# %% [markdown]
# <a href="https://colab.research.google.com/github/TaeHyeon-Kim00/26-2-DIP-TaehyeonKim/blob/main/notebook_2026/Lab00_ImageLoad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Image file(s)
# - 직접 찍은 본인이 좋아하는 사진을 업로드하기.
# - matplotlib의 imread 이용하여 image data로 불러오기.
# - Image의 데이터타입과 공간해상도를 확인하기.
# - matplotlib의 imshow로 image를 display하고, 적절한 제목을 붙여주기.

# %%
I = plt.imread('IMG_8921.jpeg')
print(I.dtype, I.shape)
plt.imshow(I)
plt.title('A beautiful boy from Laos')
plt.show()
# Out:
# uint8 (4032, 2268, 3)

# %% [markdown]
# - Image file의 metadata를 확인하기

# %%
from PIL import Image
from PIL.ExifTags import TAGS

# %%
I = Image.open('IMG_8921.jpeg')
exifdata = I.getexif()
for tag_id in exifdata:
    tag = TAGS.get(tag_id, tag_id)
    data = exifdata.get(tag_id)
    print(f"{tag:25}: {data}")
# Out:
# GPSInfo                  : 2896
# ResolutionUnit           : 2
# ExifOffset               : 244
# Make                     : Apple
# Model                    : iPhone 17 Pro Max
# Software                 : 26.5.2
# Orientation              : 1
# DateTime                 : 2026:07:14 17:32:13
# YCbCrPositioning         : 1
# XResolution              : 72.0
# YResolution              : 72.0
# HostComputer             : iPhone 17 Pro Max

# %% [markdown]
# # 2. DICOM

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.2-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 21.1 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.2

# %%
import pydicom

# %%
dcm = pydicom.dcmread('IM-0001-0001.dcm')

# %%
print("modality:",dcm.Modality)
print("hospital:",dcm.InstitutionName)
print("voxelsize:",dcm.PixelSpacing)
print("slice thickness:",dcm.SliceThickness)
# Out:
# modality: MR
# hospital: HUFS
# voxelsize: [0.381944, 0.381944]
# slice thickness: 70

# %%
f = dcm.pixel_array
print(f.shape)
print("Lmin : ",np.min(f))
print("Lmax : ",np.max(f))
# Out:
# (576, 522)
# Lmin :  0
# Lmax :  1574

# %%
plt.figure(dpi=128)
plt.imshow(f,vmin=np.min(f),vmax=np.max(f),cmap='gray')
plt.colorbar()
plt.axis('off')
plt.title('Time of Flight MR angiography')
plt.show()

# %%
f_inv = np.max(f)-f
plt.figure(dpi=128)
plt.imshow(f_inv,vmin=np.min(f_inv),vmax=np.max(f_inv),cmap='gray')
plt.colorbar()
plt.axis('off')
plt.title('Time of Flight MR angiography (inverted)')
plt.show()

# %% [markdown]
# # 3. Nifti (nii or nii.gz)

# %%
# !pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.13/dist-packages (5.4.2)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.13/dist-packages (from nibabel) (2.1.3)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.13/dist-packages (from nibabel) (26.3)

# %%
import nibabel as nib

# %%
h = nib.load('volume-covid19-A-0700_day000.nii.gz')
print(h.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/nibabel/loadsave.py in load(filename, **kwargs)
#     103     try:
# --> 104         stat_result = os.stat(filename)
#     105     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'volume-covid19-A-0700_day000.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_542/663264968.py in <cell line: 0>()
# ----> 1 h = nib.load('volume-covid19-A-0700_day000.nii.gz')
#       2 print(h.shape)
#
# /usr/local/lib/python3.13/dist-packages/nibabel/loadsave.py in load(filename, **kwargs)
#     104         stat_result = os.stat(filename)
#     105     except OSError:
# --> 106         raise FileNotFoundError(f"No such file or no access: '{filename}'")
#     107     if stat_result.st_size <= 0:
#     108         raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: 'volume-covid19-A-0700_day000.nii.gz'

# %%
print(h.header)

# %%
ct_base = h.get_fdata()
print(ct_base.dtype, ct_base.shape)
print(np.min(ct_base),np.max(ct_base))

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(ct_base[:,:,30],vmin=-1500,vmax=500,cmap='gray')
plt.subplot(132)
plt.imshow(ct_base[:,:,40],vmin=-1500,vmax=500,cmap='gray')
plt.subplot(133)
plt.imshow(ct_base[:,:,50],vmin=-1500,vmax=500,cmap='gray')
plt.tight_layout()
plt.show()

# %% [markdown]
# - day015 및 day015를 day000에 registration한 파일을 각각 불러오기.
# - day000을 포함하여 세 ct영상데이터의 동일한 단면을 display하여 비교하기.

# %%
ct_FU = nib.load('volume-covid19-A-0700_day015.nii.gz').get_fdata()
ct_FU_reg = nib.load('volume-covid19-A-0700_day015-reg_to_day000.nii.gz').get_fdata()

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(ct_base[:,:,30],vmin=-1500,vmax=500,cmap='gray')
plt.subplot(132)
plt.imshow(ct_FU[:,:,30],vmin=-1500,vmax=500,cmap='gray')
plt.subplot(133)
plt.imshow(ct_FU_reg[:,:,30],vmin=-1500,vmax=500,cmap='gray')
plt.tight_layout()
plt.show()
